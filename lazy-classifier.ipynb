# %% [markdown]
# ## Import Needed Libraries

# %%
! pip install lazypredict
# Out:
# Collecting lazypredict
#   Downloading lazypredict-0.2.12-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: click in /opt/conda/lib/python3.10/site-packages (from lazypredict) (8.1.7)
# Requirement already satisfied: scikit-learn in /opt/conda/lib/python3.10/site-packages (from lazypredict) (1.2.2)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (from lazypredict) (2.0.3)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from lazypredict) (4.66.1)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.10/site-packages (from lazypredict) (1.3.2)
# Requirement already satisfied: lightgbm in /opt/conda/lib/python3.10/site-packages (from lazypredict) (3.3.2)
# Requirement already satisfied: xgboost in /opt/conda/lib/python3.10/site-packages (from lazypredict) (2.0.2)
# Requirement already satisfied: wheel in /opt/conda/lib/python3.10/site-packages (from lightgbm->lazypredict) (0.41.2)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from lightgbm->lazypredict) (1.24.3)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (from lightgbm->lazypredict) (1.11.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->lazypredict) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas->lazypredict) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas->lazypredict) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.10/site-packages (from pandas->lazypredict) (2023.3)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->lazypredict) (1.16.0)
# Installing collected packages: lazypredict
# Successfully installed lazypredict-0.2.12

# %%
import numpy as np 
import pandas as pd

import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from lazypredict.Supervised import LazyClassifier

# %% [markdown]
# ## EDA

# %%
df = pd.read_csv('/kaggle/input/heart-failure-prediction/heart.csv')
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N     0.00       Up             0
# 1              N     1.00     Flat             1
# 2              N     0.00       Up             0
# 3              Y     1.50     Flat             1
# 4              N     0.00       Up             0

# %% [markdown]
# ## Preprocessing
#
#
# **Define features X and Target y**

# %%
x = df.iloc[:, :-1]
y = df.iloc[:, -1]

# %% [markdown]
# ## Encode string columns

# %%
StandardScalerModel = StandardScaler()
x = StandardScalerModel.fit_transform(x)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_42/2429692855.py in ?()
#       1 StandardScalerModel = StandardScaler()
# ----> 2 x = StandardScalerModel.fit_transform(x)
#
# /opt/conda/lib/python3.10/site-packages/sklearn/utils/_set_output.py in ?(self, X, *args, **kwargs)
#     138     @wraps(f)
#     139     def wrapped(self, X, *args, **kwargs):
# --> 140         data_to_wrap = f(self, X, *args, **kwargs)
#     141         if isinstance(data_to_wrap, tuple):
#     142             # only wrap the first output for cross decomposition
#     143             return (
#
# /opt/conda/lib/python3.10/site-packages/sklearn/base.py in ?(self, X, y, **fit_params)
#     874         # non-optimized default implementation; override when a better
#     875         # method is possible for a given clustering algorithm
#     876         if y is None:
#     877             # fit method of arity 1 (unsupervised transformation)
# --> 878             return self.fit(X, **fit_params).transform(X)
#     879         else:
#     880             # fit method of arity 2 (supervised transformation)
#     881             return self.fit(X, y, **fit_params).transform(X)
#
# /opt/conda/lib/python3.10/site-packages/sklearn/preprocessing/_data.py in ?(self, X, y, sample_weight)
#     820             Fitted scaler.
#     821         """
#     822         # Reset internal state before fitting
#     823         self._reset()
# --> 824         return self.partial_fit(X, y, sample_weight)
#
# /opt/conda/lib/python3.10/site-packages/sklearn/preprocessing/_data.py in ?(self, X, y, sample_weight)
#     857         """
#     858         self._validate_params()
#     859
#     860         first_call = not hasattr(self, "n_samples_seen_")
# --> 861         X = self._validate_data(
#     862             X,
#     863             accept_sparse=("csr", "csc"),
#     864             dtype=FLOAT_DTYPES,
#
# /opt/conda/lib/python3.10/site-packages/sklearn/base.py in ?(self, X, y, reset, validate_separately, **check_params)
#     561
#     562         if no_val_X and no_val_y:
#     563             raise ValueError("Validation should be done on X, y or both.")
#     564         elif not no_val_X and no_val_y:
# --> 565             X = check_array(X, input_name="X", **check_params)
#     566             out = X
#     567         elif no_val_X and not no_val_y:
#     568             y = _check_y(y, **check_params)
#
# /opt/conda/lib/python3.10/site-packages/sklearn/utils/validation.py in ?(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     876                         )
#     877                     array = xp.astype(array, dtype, copy=False)
#     878                 else:
#     879                     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
# --> 880             except ComplexWarning as complex_warning:
#     881                 raise ValueError(
#     882                     "Complex data not supported\n{}\n".format(array)
#     883                 ) from complex_warning
#
# /opt/conda/lib/python3.10/site-packages/sklearn/utils/_array_api.py in ?(array, dtype, order, copy, xp)
#     181     if xp is None:
#     182         xp, _ = get_namespace(array)
#     183     if xp.__name__ in {"numpy", "numpy.array_api"}:
#     184         # Use NumPy API to support order
# --> 185         array = numpy.asarray(array, order=order, dtype=dtype)
#     186         return xp.asarray(array, copy=copy)
#     187     else:
#     188         return xp.asarray(array, dtype=dtype, copy=copy)
#
# /opt/conda/lib/python3.10/site-packages/pandas/core/generic.py in ?(self, dtype)
#    1996     def __array__(self, dtype: npt.DTypeLike | None = None) -> np.ndarray:
#    1997         values = self._values
# -> 1998         arr = np.asarray(values, dtype=dtype)
#    1999         if (
#    2000             astype_is_view(values.dtype, arr.dtype)
#    2001             and using_copy_on_write()
#
# ValueError: could not convert string to float: 'M'

# %% [markdown]
# ## Split data into train and test

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0, shuffle=True)

# %% [markdown]
# ## Create Model

# %%
clf = LazyClassifier(verbose=1)
models, predictions = clf.fit(x_train, x_test, y_train, y_test)
# Out:
#  10%|█         | 3/29 [00:00<00:02,  9.52it/s]
# {'Model': 'AdaBoostClassifier', 'Accuracy': 0.842391304347826, 'Balanced Accuracy': 0.8335356232552494, 'ROC AUC': 0.8335356232552494, 'F1 Score': 0.8415460491690352, 'Time taken': 0.20981192588806152}
# {'Model': 'BaggingClassifier', 'Accuracy': 0.8260869565217391, 'Balanced Accuracy': 0.823158150260954, 'ROC AUC': 0.823158150260954, 'F1 Score': 0.8263814391788141, 'Time taken': 0.08686375617980957}
# {'Model': 'BernoulliNB', 'Accuracy': 0.8206521739130435, 'Balanced Accuracy': 0.8166646437674475, 'ROC AUC': 0.8166646437674474, 'F1 Score': 0.8208097110009284, 'Time taken': 0.048226118087768555}
#  28%|██▊       | 8/29 [00:00<00:01, 13.99it/s]
# {'Model': 'CalibratedClassifierCV', 'Accuracy': 0.8315217391304348, 'Balanced Accuracy': 0.8187280009709916, 'ROC AUC': 0.8187280009709916, 'F1 Score': 0.8296928889815183, 'Time taken': 0.2108769416809082}
# {'Model': 'DecisionTreeClassifier', 'Accuracy': 0.7445652173913043, 'Balanced Accuracy': 0.751244083019784, 'ROC AUC': 0.751244083019784, 'F1 Score': 0.7462741414817851, 'Time taken': 0.03826594352722168}
# {'Model': 'DummyClassifier', 'Accuracy': 0.5815217391304348, 'Balanced Accuracy': 0.5, 'ROC AUC': 0.5, 'F1 Score': 0.4276482892574332, 'Time taken': 0.032814741134643555}
# {'Model': 'ExtraTreeClassifier', 'Accuracy': 0.8369565217391305, 'Balanced Accuracy': 0.8325039446534774, 'ROC AUC': 0.8325039446534774, 'F1 Score': 0.8369565217391305, 'Time taken': 0.03322911262512207}
#  34%|███▍      | 10/29 [00:01<00:01,  9.89it/s]
# {'Model': 'ExtraTreesClassifier', 'Accuracy': 0.8641304347826086, 'Balanced Accuracy': 0.8558684306347858, 'ROC AUC': 0.8558684306347858, 'F1 Score': 0.8634017665250302, 'Time taken': 0.2871358394622803}
# {'Model': 'GaussianNB', 'Accuracy': 0.842391304347826, 'Balanced Accuracy': 0.8353562325524942, 'ROC AUC': 0.8353562325524941, 'F1 Score': 0.8419151160831219, 'Time taken': 0.03239774703979492}
# {'Model': 'KNeighborsClassifier', 'Accuracy': 0.8478260869565217, 'Balanced Accuracy': 0.8454909576404903, 'ROC AUC': 0.8454909576404904, 'F1 Score': 0.8480837592814623, 'Time taken': 0.09688472747802734}
#  41%|████▏     | 12/29 [00:01<00:01,  8.61it/s]
# {'Model': 'LabelPropagation', 'Accuracy': 0.8152173913043478, 'Balanced Accuracy': 0.8119917465711859, 'ROC AUC': 0.8119917465711858, 'F1 Score': 0.81553027912749, 'Time taken': 0.19661521911621094}
#  48%|████▊     | 14/29 [00:01<00:02,  6.96it/s]
# {'Model': 'LabelSpreading', 'Accuracy': 0.8152173913043478, 'Balanced Accuracy': 0.8119917465711859, 'ROC AUC': 0.8119917465711858, 'F1 Score': 0.81553027912749, 'Time taken': 0.23851656913757324}
# {'Model': 'LinearDiscriminantAnalysis', 'Accuracy': 0.8260869565217391, 'Balanced Accuracy': 0.8158757130719747, 'ROC AUC': 0.8158757130719747, 'F1 Score': 0.8249332336288858, 'Time taken': 0.16356682777404785}
#  55%|█████▌    | 16/29 [00:01<00:01,  7.53it/s]
# {'Model': 'LinearSVC', 'Accuracy': 0.8315217391304348, 'Balanced Accuracy': 0.8187280009709916, 'ROC AUC': 0.8187280009709916, 'F1 Score': 0.8296928889815183, 'Time taken': 0.09515666961669922}
# {'Model': 'LogisticRegression', 'Accuracy': 0.8260869565217391, 'Balanced Accuracy': 0.8122344944774851, 'ROC AUC': 0.8122344944774851, 'F1 Score': 0.8239302967563837, 'Time taken': 0.12066984176635742}
#  72%|███████▏  | 21/29 [00:02<00:00, 11.90it/s]
# {'Model': 'NearestCentroid', 'Accuracy': 0.8369565217391305, 'Balanced Accuracy': 0.8361451632479671, 'ROC AUC': 0.836145163247967, 'F1 Score': 0.8374675682050475, 'Time taken': 0.08021116256713867}
# {'Model': 'NuSVC', 'Accuracy': 0.8478260869565217, 'Balanced Accuracy': 0.8382085204515111, 'ROC AUC': 0.8382085204515112, 'F1 Score': 0.8468165794252751, 'Time taken': 0.054666996002197266}
# {'Model': 'PassiveAggressiveClassifier', 'Accuracy': 0.8260869565217391, 'Balanced Accuracy': 0.8158757130719747, 'ROC AUC': 0.8158757130719747, 'F1 Score': 0.8249332336288858, 'Time taken': 0.035085201263427734}
# {'Model': 'Perceptron', 'Accuracy': 0.7228260869565217, 'Balanced Accuracy': 0.754399805801675, 'ROC AUC': 0.754399805801675, 'F1 Score': 0.7182266801410941, 'Time taken': 0.031700849533081055}
# {'Model': 'QuadraticDiscriminantAnalysis', 'Accuracy': 0.8043478260869565, 'Balanced Accuracy': 0.7844398592062143, 'ROC AUC': 0.7844398592062143, 'F1 Score': 0.7998109640831758, 'Time taken': 0.043146371841430664}
#  79%|███████▉  | 23/29 [00:02<00:00,  8.02it/s]
# {'Model': 'RandomForestClassifier', 'Accuracy': 0.8586956521739131, 'Balanced Accuracy': 0.8493749241412794, 'ROC AUC': 0.8493749241412792, 'F1 Score': 0.8577582523234698, 'Time taken': 0.32547450065612793}
# {'Model': 'RidgeClassifier', 'Accuracy': 0.8260869565217391, 'Balanced Accuracy': 0.8158757130719747, 'ROC AUC': 0.8158757130719747, 'F1 Score': 0.8249332336288858, 'Time taken': 0.13772034645080566}
#  86%|████████▌ | 25/29 [00:02<00:00,  8.11it/s]
# {'Model': 'RidgeClassifierCV', 'Accuracy': 0.8260869565217391, 'Balanced Accuracy': 0.8158757130719747, 'ROC AUC': 0.8158757130719747, 'F1 Score': 0.8249332336288858, 'Time taken': 0.1744685173034668}
# {'Model': 'SGDClassifier', 'Accuracy': 0.8369565217391305, 'Balanced Accuracy': 0.8197596795727637, 'ROC AUC': 0.8197596795727637, 'F1 Score': 0.8338100686498855, 'Time taken': 0.056984901428222656}
# {'Model': 'SVC', 'Accuracy': 0.8478260869565217, 'Balanced Accuracy': 0.8382085204515111, 'ROC AUC': 0.8382085204515112, 'F1 Score': 0.8468165794252751, 'Time taken': 0.0636594295501709}
#  97%|█████████▋| 28/29 [00:03<00:00,  9.55it/s]
# {'Model': 'XGBClassifier', 'Accuracy': 0.8478260869565217, 'Balanced Accuracy': 0.8400291297487559, 'ROC AUC': 0.8400291297487559, 'F1 Score': 0.8471931923946283, 'Time taken': 0.15651512145996094}
# 100%|██████████| 29/29 [00:04<00:00,  6.89it/s]
# {'Model': 'LGBMClassifier', 'Accuracy': 0.8641304347826086, 'Balanced Accuracy': 0.8595096492292754, 'ROC AUC': 0.8595096492292755, 'F1 Score': 0.8640023923286874, 'Time taken': 1.0910520553588867}

# %%
print(models)
# Out:
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# LGBMClassifier                     0.86               0.86     0.86      0.86
# ExtraTreesClassifier               0.86               0.86     0.86      0.86
# RandomForestClassifier             0.86               0.85     0.85      0.86
# KNeighborsClassifier               0.85               0.85     0.85      0.85
# XGBClassifier                      0.85               0.84     0.84      0.85
# SVC                                0.85               0.84     0.84      0.85
# NuSVC                              0.85               0.84     0.84      0.85
# NearestCentroid                    0.84               0.84     0.84      0.84
# GaussianNB                         0.84               0.84     0.84      0.84
# AdaBoostClassifier                 0.84               0.83     0.83      0.84
# ExtraTreeClassifier                0.84               0.83     0.83      0.84
# BaggingClassifier                  0.83               0.82     0.82      0.83
# SGDClassifier                      0.84               0.82     0.82      0.83
# LinearSVC                          0.83               0.82     0.82      0.83
# CalibratedClassifierCV             0.83               0.82     0.82      0.83
# BernoulliNB                        0.82               0.82     0.82      0.82
# RidgeClassifier                    0.83               0.82     0.82      0.82
# LinearDiscriminantAnalysis         0.83               0.82     0.82      0.82
# PassiveAggressiveClassifier        0.83               0.82     0.82      0.82
# RidgeClassifierCV                  0.83               0.82     0.82      0.82
# LogisticRegression                 0.83               0.81     0.81      0.82
# LabelPropagation                   0.82               0.81     0.81      0.82
# LabelSpreading                     0.82               0.81     0.81      0.82
# QuadraticDiscriminantAnalysis      0.80               0.78     0.78      0.80
# Perceptron                         0.72               0.75     0.75      0.72
# DecisionTreeClassifier             0.74               0.75     0.75      0.75
# DummyClassifier                    0.58               0.50     0.50      0.43
#
#                                Time Taken
# Model
# LGBMClassifier                       1.09
# ExtraTreesClassifier                 0.29
# RandomForestClassifier               0.33
# KNeighborsClassifier                 0.10
# XGBClassifier                        0.16
# SVC                                  0.06
# NuSVC                                0.05
# NearestCentroid                      0.08
# GaussianNB                           0.03
# AdaBoostClassifier                   0.21
# ExtraTreeClassifier                  0.03
# BaggingClassifier                    0.09
# SGDClassifier                        0.06
# LinearSVC                            0.10
# CalibratedClassifierCV               0.21
# BernoulliNB                          0.05
# RidgeClassifier                      0.14
# LinearDiscriminantAnalysis           0.16
# PassiveAggressiveClassifier          0.04
# RidgeClassifierCV                    0.17
# LogisticRegression                   0.12
# LabelPropagation                     0.20
# LabelSpreading                       0.24
# QuadraticDiscriminantAnalysis        0.04
# Perceptron                           0.03
# DecisionTreeClassifier               0.04
# DummyClassifier                      0.03
